# %%
import pandas as pd
import numpy as np

dist = '/Users/mariama/Documents/GitHub/small-things/urgent_care_project/distance_2018.csv'
distances = pd.read_csv(dist, encoding = "ISO-8859-1")
distances.head()
# Out:
#    Unnamed: 0  STATEFP  COUNTYFP  TRACTCE  POPULATION_x   LATITUDE  LONGITUDE  \
# 0           0        1         1    20100          1912  32.475973 -86.486772
# 1           1        1         1    20200          2170  32.471763 -86.472782
# 2           2        1         1    20300          3373  32.474011 -86.459639
# 3           3        1         1    20400          4386  32.468685 -86.443021
# 4           4        1         1    20500         10766  32.465330 -86.423696
#
#    hosp_index      dist          Y  ...   COUNTYFIPS  COUNTRY        LAT  \
# 0        3858  3.505897 -86.452253  ...         1001      USA  32.463892
# 1        3858  2.115474 -86.452253  ...         1001      USA  32.463892
# 2        3858  1.321450 -86.452253  ...         1001      USA  32.463892
# 3        3858  1.016961 -86.452253  ...         1001      USA  32.463892
# 4        3858  2.683916 -86.452253  ...         1001      USA  32.463892
#
# ...

# %%
import matplotlib.pyplot as plt

a = np.hstack((distances['dist']))

plt.hist(distances['dist'], bins = 'auto')
plt.show()
